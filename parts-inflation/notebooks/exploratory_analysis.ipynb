# %% [markdown]
# # Exploratory analysis
#
# Production calculations live in `parts_inflation` modules. Use this notebook for ad-hoc profiling only.

# %%
from pathlib import Path
from parts_inflation.ingest import profile_sources
from parts_inflation.config import project_root

profile_sources(project_root() / 'data' / 'raw')
